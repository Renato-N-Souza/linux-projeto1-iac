# %% [markdown]
# <a href="https://colab.research.google.com/github/Renato-N-Souza/linux-projeto1-iac/blob/main/Aps2_cores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow                #instalando a biblioteca
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import PIL                         #importando a biblioteca instalada

from numpy import asarray

# %%
print('Pillow Version:', PIL.__version__)      #vendo a versão
#print('PIL Version:', PIL.VERSION)
# Out:
# Pillow Version: 7.1.2

# %%
from PIL import Image                  #importando o pacote image da biblioteca PIL

# %%
image = Image.open("sample_data/cores.jpeg")         #carregando a imagem
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=603x512 at 0x7EFFAD8227D0>

# %%
print(image.format)       #mostrando o formato do arquivo original
# Out:
# PNG

# %%
print(image.mode)          #modo da imagem
# Out:
# RGBA

# %%
print(image.size)        #tamanho da imagem
# Out:
# (603, 512)

# %%
from matplotlib import image
from matplotlib import pyplot

# %%
data = image.imread("sample_data/cores.jpeg")       #carregando a imagem como um array
print(data)
# Out:
# [[[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  ...
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]]

# %%
print(data.dtype)        #tipo de dado
# Out:
# uint8

# %%
print(data.shape)      #forma do array
# Out:
# (512, 603, 4)

# %%
print(data.max())       #valor maximo
# Out:
# 255

# %%
print(data.min())      #valor minimo
# Out:
# 0

# %%
pyplot.imshow(data)          #array de pixel como imagem

# %%
image2=Image.fromarray(data)            # convertendo o array de pixels em objeto pillow
image2
# Out:
# <PIL.Image.Image image mode=RGBA size=603x512 at 0x7EFFAC59AB90>

# %%
type(image2)     #tipo da imagem
# Out:
# PIL.Image.Image

# %%
image=Image.open("sample_data/cores.jpeg")            #convertendo objeto de tipo image para array
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=603x512 at 0x7EFFAC128810>

# %%
data = asarray(image)     #método asarray para realizar a conversão

# %%
print(data.dtype)                 #mostrando o tipo de dado
# Out:
# uint8

# %%
print(data.shape)
# Out:
# (512, 603, 4)

# %%
image.save("sample_data/cores.png",format="PNG")      #salvando a imagem em png

# %%
image.save("sample_data/cores.gif",format="GIF")     #salvando a imagem em gif

# %%
image3=Image.open("sample_data/cores.gif")           #carregando a imagem e verificando o formato
print(image3.format)
# Out:
# GIF

# %%
image_cinza=image.convert(mode = "L")      #modo cinza

# %%
image_cinza
# Out:
# <PIL.Image.Image image mode=L size=603x512 at 0x7EFFAC5BEF90>

# %%
image_cinza.save("sample_data/cores_cinza.jpg")          #salvando a imagem em cinza

# %%
print(image.size)                  #tamanho da imagem
# Out:
# (603, 512)

# %%
image.thumbnail((150,150))
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=150x127 at 0x7EFFAC128810>

# %%
print(image.size)
# Out:
# (150, 127)

# %%
image = Image.open("sample_data/cores.jpeg")

# %%
image_resize = image.resize((350,250))

# %%
print(image_resize.size)
# Out:
# (350, 250)

# %%
pyplot.imshow(image_resize)

# %%
horizontal_image = image.transpose(Image.FLIP_LEFT_RIGHT)

# %%
pyplot.imshow(horizontal_image)

# %%
vertical_image = image.transpose(Image.FLIP_TOP_BOTTOM)

# %%
pyplot.imshow(vertical_image)

# %%
image = Image.open("sample_data/cores.jpeg")

# %%
pyplot.imshow(image.rotate(45))

# %%
pyplot.imshow(image.rotate(90
))

# %%
pyplot.imshow(image)

# %%
pyplot.imshow(image.crop((300,100,700,500)))

# %%
image = Image.open("sample_data/cores.jpeg")

# %%
pixels = asarray(image)

# %%
pixels
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
pixels = pixels.astype('float32')

# %%
pixels /= pixels.max()
